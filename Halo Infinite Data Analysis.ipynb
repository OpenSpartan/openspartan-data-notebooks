# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import urllib.request

# %%
# Catalyst
#target_map_url = "https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/e859cf75-9b8a-429a-91be-2376681c8537/977c8fe8-8087-4a48-864d-52b4eeee8765/stats.tsv"

# Launch Site
#target_map_url = "https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/56a11b8c-64d1-4537-8893-a9241e4d5b93/7804214e-c463-49e9-b269-d22694142916/stats.tsv"

# Streets
#target_map_url = "https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/f0a1760f-0d4a-4bcc-ac7a-e8f9aee331dc/6e9da6f4-fb07-4d38-b26e-2136941d5531/stats.tsv"

# Bazaar
#target_map_url = "https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/298d5036-cd43-47b3-a4bd-31e127566593/a5582547-29fb-4ceb-ac9d-74f899901501/stats.tsv"

# Live Fire
#target_map_url = "https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/b6aca0c7-8ba7-4066-bf91-693571374c3c/c63ee410-784e-46ae-911e-ab7bc35933b1/stats.tsv"

# Arena - Land Grab
target_map_url = 'https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/game_variants/8d6e16cd-7e95-4166-92fd-d280163b7ab7/6ce17bcf-6af5-4d26-9181-9583ed35af56/stats.tsv'
urllib.request.urlretrieve(target_map_url, "data.tsv")
# Out:
# ('data.tsv', <http.client.HTTPMessage at 0x1b033af6d40>)

# %%
df = pd.read_csv('data.tsv', sep='\t', parse_dates=['SnapshotTime'])
df.head(5)
# Out:
#          SnapshotTime  RecentPlays  AllTimePlays  Favorites  Likes  Bookmarks  \
# 0 2022-06-22 03:37:55       626683       1847097       1839      0          0
# 1 2022-06-22 03:43:21       626450       1847182       1839      0          0
# 2 2022-06-22 03:53:20       625868       1847401       1839      0          0
# 3 2022-06-22 03:56:09       625501       1847526       1839      0          0
# 4 2022-06-22 04:09:43       624704       1847775       1839      0          0
#
#    AverageRating  NumberOfRatings
# 0       3.058661             1449
# 1       3.058661             1449
# 2       3.058661             1449
# 3       3.058661             1449
# 4       3.058661             1449

# %%
#plt.rcParams['figure.figsize'] = [17, 10]
#plt.rcParams['font.size']=12                
#plt.rcParams['savefig.dpi']=100             
plt.rcParams['figure.subplot.bottom']=.1

ax = plt.gca()
ax.ticklabel_format(axis="y", useOffset=False)

# %%
plt.figure()
plt.xticks(rotation=90)
plt.plot(df.SnapshotTime, df.AllTimePlays)

# %%
# %matplotlib notebook

plt.figure()
plt.xticks(rotation=90)
plt.plot(df.SnapshotTime, df.RecentPlays)
# Out:
# <img src="data:image/png;base64,..." width="956">
