# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import urllib.request

# %%
# Download data for the Live Fire map.
urllib.request.urlretrieve("https://raw.githubusercontent.com/dend/openspartan-data-snapshots/main/data/maps/b6aca0c7-8ba7-4066-bf91-693571374c3c/c63ee410-784e-46ae-911e-ab7bc35933b1/stats.tsv", "data.tsv")
# Out:
# ('data.tsv', <http.client.HTTPMessage at 0x29b3aab2320>)

# %%
df = pd.read_csv('data.tsv', sep='\t')
df.head(5)
# Out:
#            SnapshotTime  RecentPlays  AllTimePlays  Favorites  Likes  \
# 0  6/22/2022 3:37:55 AM       277425      28401948       3618      0
# 1  6/22/2022 3:43:21 AM       277504      28402208       3618      0
# 2  6/22/2022 3:53:20 AM       277631      28402708       3618      0
# 3  6/22/2022 3:56:09 AM       277637      28402745       3618      0
# 4  6/22/2022 4:09:43 AM       277731      28403166       3618      0
#
#    Bookmarks  AverageRating  NumberOfRatings
# 0          0       3.861309             3086
# 1          0       3.861309             3086
# 2          0       3.861309             3086
# 3          0       3.861309             3086
# 4          0       3.861309             3086

# %%
plt.rcParams['figure.figsize'] = [14, 7]

# %%
plt.xticks(rotation=90)
plt.plot(df.SnapshotTime, df.AllTimePlays)

# %%
plt.xticks(rotation=90)
plt.plot(df.SnapshotTime, df.RecentPlays)
